# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
music_df = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/musica_integracionv2.csv')

# %%
# Cargar el dataset
music_df = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/musica_integracionv2.csv')

# Mostrar la información general del dataset
print(music_df.info())

# Mostrar las primeras filas del dataset para ver el contenido de las columnas
print(music_df.head())

# Revisar si hay valores nulos en las columnas
print(music_df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56192 entries, 0 to 56191
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  56192 non-null  int64
#  1   Username    56192 non-null  object
#  2   Artist      56192 non-null  object
#  3   Track       56192 non-null  object
#  4   Album       56192 non-null  object
#  5   Date        56192 non-null  object
#  6   Time        56192 non-null  object
#  7   Genre       56192 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 3.4+ MB
# None
#    Unnamed: 0 Username           Artist                          Track  \
# 0           0  Babs_05  Isobel Campbell     The Circus Is Leaving Town
# 1           1  Babs_05  Isobel Campbell                   Dusty Wreath
# 2           2  Babs_05  Isobel Campbell     Honey Child What Can I Do?
# 3           3  Babs_05  Isobel Campbell  It's Hard To Kill A Bad Thing
# ...

# %%
# Revisar la distribución de valores en la columna 'Genre'
genre_distribution = netflix_df['listed_in'].value_counts()

# Revisar si hay valores NaN en 'Genre'
nan_genre_count = netflix_df['listed_in'].isnull().sum()

print("Distribución de valores en 'listed_in':")
print(genre_distribution)
print(f"\nCantidad de valores NaN en 'listed_in': {nan_genre_count}")
# Out:
# Distribución de valores en 'listed_in':
# listed_in
# Documentaries                                                                      334
# Stand-Up Comedy                                                                    321
# Dramas, International Movies                                                       320
# Comedies, Dramas, International Movies                                             243
# Dramas, Independent Movies, International Movies                                   215
#                                                                                   ...
# Reality TV, TV Horror, TV Thrillers                                                  1
# Classic & Cult TV, TV Horror, TV Mysteries                                           1
# Dramas, Horror Movies, Sci-Fi & Fantasy                                              1
# TV Comedies, TV Dramas, TV Sci-Fi & Fantasy                                          1
# ...

# %%
# Eliminar la columna 'Unnamed: 0'
music_df.drop(columns=['Unnamed: 0'], inplace=True)

# Revisar los géneros únicos en la columna 'Genre'
unique_genres = music_df['Genre'].unique()
print("Géneros únicos antes de limpiar:")
print(unique_genres)

# Limpiar y estandarizar la columna 'Genre' (si es necesario)
# Por ejemplo, eliminar espacios o caracteres especiales
music_df['Genre'] = music_df['Genre'].str.strip()

# Crear la columna `bert_input` combinando columnas relevantes
music_df['bert_input'] = (
    music_df['Artist'] + " | " +
    music_df['Track'] + " | " +
    music_df['Album'] + " | " +
    music_df['Genre']
)

# Añadir columna 'emotion' vacía
music_df['emotion'] = None

# Guardar el dataset preparado
output_path = "/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv"
music_df.to_csv(output_path, index=False)

print(f"Dataset preparado y guardado en: {output_path}")
# Out:
# Géneros únicos antes de limpiar:
# ['Alternative/Indie' 'Electronic' 'Pop' 'Hip-Hop/Rap' 'Classical'
#  'Soundtrack' 'Blues/Jazz' 'Musical' 'Experimental' 'Metal' 'Country/Folk'
#  'Rock']
# Dataset preparado y guardado en: /content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv

# %%
music_df = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv')

# %%
print(music_df['Time'].head())
# Out:
# 0     23:36
# 1     23:32
# 2     23:28
# 3     23:25
# 4     23:21
# Name: Time, dtype: object

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56192 entries, 0 to 56191
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    56192 non-null  object
#  1   Artist      56192 non-null  object
#  2   Track       56192 non-null  object
#  3   Album       56192 non-null  object
#  4   Date        56192 non-null  object
#  5   Time        56192 non-null  object
#  6   Genre       56192 non-null  object
#  7   bert_input  56192 non-null  object
#  8   emotion     0 non-null      float64
# dtypes: float64(1), object(8)
# memory usage: 3.9+ MB

# %%
# Verificar valores nulos en las columnas relevantes
null_counts = music_df[['bert_input', 'emotion']].isnull().sum()
print("\nValores nulos en columnas relevantes:")
print(null_counts)
# Out:
# Valores nulos en columnas relevantes:
# bert_input        0
# emotion       56192
# dtype: int64

# %%
# Verificar duplicados en 'bert_input'
duplicates_count = music_df.duplicated(subset=['bert_input']).sum()
print(f"Número de duplicados en 'bert_input': {duplicates_count}")
# Out:
# Número de duplicados en 'bert_input': 26073

# %%
# Verificar el tipo de datos y los primeros registros en la columna 'Time'
print(music_df['Time'].dtype)
print(music_df['Time'].head(10))
# Out:
# object
# 0     23:36
# 1     23:32
# 2     23:28
# 3     23:25
# 4     23:21
# 5     23:17
# 6     23:14
# 7     23:11
# 8     23:08
# 9     23:04
# Name: Time, dtype: object

# %%
import pandas as pd

# Cargar el dataset
file_path = "/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv"
music_df = pd.read_csv(file_path)

# Limpiar posibles espacios en la columna 'Time'
music_df['Time'] = music_df['Time'].str.strip()

# Intentar convertir 'Time' a formato timedelta
music_df['Time'] = pd.to_timedelta(music_df['Time'] + ':00', errors='coerce')

# Verificar los primeros registros después de la conversión
print(music_df[['Date', 'Time']].head())

print(f"Dataset con tiempos corregidos guardado en: {output_path}")
# Out:
#           Date            Time
# 0  31 Jan 2021 0 days 23:36:00
# 1  31 Jan 2021 0 days 23:32:00
# 2  31 Jan 2021 0 days 23:28:00
# 3  31 Jan 2021 0 days 23:25:00
# 4  31 Jan 2021 0 days 23:21:00
# Dataset con tiempos corregidos guardado en: /content/drive/MyDrive/TFM/Datasets/music_with_corrected_dates_v2.csv

# %%
music_df.to_csv('/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv', index=False)

# %%
music_df = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv')

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56192 entries, 0 to 56191
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    56192 non-null  object
#  1   Artist      56192 non-null  object
#  2   Track       56192 non-null  object
#  3   Album       56192 non-null  object
#  4   Date        56192 non-null  object
#  5   Time        56192 non-null  object
#  6   Genre       56192 non-null  object
#  7   bert_input  56192 non-null  object
#  8   emotion     0 non-null      float64
# dtypes: float64(1), object(8)
# memory usage: 3.9+ MB

# %%
music_df.Time.unique()
# Out:
# array(['0 days 23:36:00', '0 days 23:32:00', '0 days 23:28:00', ...,
#        '0 days 02:33:00', '0 days 03:18:00', '0 days 06:05:00'],
#       dtype=object)

# %%
# Verificar los primeros y últimos registros del dataset
print("Primeros registros:")
print(music_df.head())

print("\nÚltimos registros:")
print(music_df.tail())
# Out:
# Primeros registros:
#   Username           Artist                          Track  \
# 0  Babs_05  Isobel Campbell     The Circus Is Leaving Town
# 1  Babs_05  Isobel Campbell                   Dusty Wreath
# 2  Babs_05  Isobel Campbell     Honey Child What Can I Do?
# 3  Babs_05  Isobel Campbell  It's Hard To Kill A Bad Thing
# 4  Babs_05  Isobel Campbell                Saturday's Gone
#
#                        Album         Date             Time              Genre  \
# 0  Ballad of the Broken Seas  31 Jan 2021  0 days 23:36:00  Alternative/Indie
# 1  Ballad of the Broken Seas  31 Jan 2021  0 days 23:32:00  Alternative/Indie
# 2  Ballad of the Broken Seas  31 Jan 2021  0 days 23:28:00  Alternative/Indie
# 3  Ballad of the Broken Seas  31 Jan 2021  0 days 23:25:00  Alternative/Indie
# 4  Ballad of the Broken Seas  31 Jan 2021  0 days 23:21:00  Alternative/Indie
#
#                                           bert_input  emotion
# ...

# %%
# Ver estadísticas generales del dataset
print(music_df.describe(include='all'))
# Out:
#        Username  Artist                         Track  \
# count     56192   56192                         56192
# unique       11   11444                         27301
# top     Babs_05  Sophie  Cascades (Dirt Road Version)
# freq      11091    1181                           297
# mean        NaN     NaN                           NaN
# std         NaN     NaN                           NaN
# min         NaN     NaN                           NaN
# 25%         NaN     NaN                           NaN
# 50%         NaN     NaN                           NaN
# 75%         NaN     NaN                           NaN
# max         NaN     NaN                           NaN
#
#                                   Album         Date             Time  Genre  \
# count                             56192        56192            56192  56192
# unique                            17486           31             1440     12
# top     OIL OF EVERY PEARL'S UN-INSIDES  31 Jan 2021  0 days 18:46:00   Rock
# ...

# %%
# Distribución de los géneros
genre_distribution = music_df['Genre'].value_counts()
print("\nDistribución de Géneros:")
print(genre_distribution)
# Out:
# Distribución de Géneros:
# Genre
# Rock                 20000
# Pop                  11041
# Alternative/Indie     9633
# Electronic            9113
# Hip-Hop/Rap           2281
# Country/Folk           972
# Blues/Jazz             709
# Musical                586
# Metal                  559
# Soundtrack             517
# Classical              473
# Experimental           308
# Name: count, dtype: int64

# %%
# Verificar los primeros registros de 'bert_input'
print("\nPrimeros registros de 'bert_input':")
print(music_df['bert_input'].head())
# Out:
# Primeros registros de 'bert_input':
# 0    Isobel Campbell | The Circus Is Leaving Town |...
# 1    Isobel Campbell | Dusty Wreath | Ballad of the...
# 2    Isobel Campbell | Honey Child What Can I Do? |...
# 3    Isobel Campbell | It's Hard To Kill A Bad Thin...
# 4    Isobel Campbell | Saturday's Gone | Ballad of ...
# Name: bert_input, dtype: object

# %%
# Verificar la longitud de los textos en 'bert_input'
music_df['bert_input_length'] = music_df['bert_input'].apply(len)

# Ver la longitud máxima
max_length = music_df['bert_input_length'].max()
print(f"Longitud máxima de 'bert_input': {max_length}")

# Ver los primeros registros con longitudes excesivas
long_inputs = music_df[music_df['bert_input_length'] > 512]
print(f"Registros con longitud excesiva de 'bert_input': {len(long_inputs)}")
# Out:
# Longitud máxima de 'bert_input': 273
# Registros con longitud excesiva de 'bert_input': 0

# %%
music_df = music_df[music_df['bert_input_length'] <= 512]

# %%
music_df.to_csv('/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv', index=False)

# %%
music_df = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv')

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56191 entries, 0 to 56190
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Username           56191 non-null  object
#  1   Artist             56191 non-null  object
#  2   Track              56191 non-null  object
#  3   Album              56191 non-null  object
#  4   Date               56191 non-null  object
#  5   Time               56191 non-null  object
#  6   Genre              56191 non-null  object
#  7   bert_input         56191 non-null  object
#  8   emotion            0 non-null      float64
#  9   bert_input_length  56191 non-null  int64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 4.3+ MB

# %%
import numpy as np
# Eliminar la columna 'bert_input_length' ahora que ya no la necesitamos
music_df.drop(columns=['bert_input_length'], inplace=True)

# Asignar un valor aleatorio de 'rating_values' a cada fila
rating_values = [2.5, 4.0, 4.5, 1.5, 2.0, 1.0, 3.0, 0.5, 3.5, 5.0]
music_df['rating'] = np.random.choice(rating_values, size=len(music_df))

# Verificar que la columna 'rating' se haya agregado correctamente
print(music_df[['Username', 'Artist', 'Track', 'rating']].head())

# Guardar el dataset final
music_df.to_csv('/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv', index=False)

print("Dataset actualizado y guardado en: /content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv")
# Out:
#   Username           Artist                          Track  rating
# 0  Babs_05  Isobel Campbell     The Circus Is Leaving Town     4.5
# 1  Babs_05  Isobel Campbell                   Dusty Wreath     5.0
# 2  Babs_05  Isobel Campbell     Honey Child What Can I Do?     2.5
# 3  Babs_05  Isobel Campbell  It's Hard To Kill A Bad Thing     2.5
# 4  Babs_05  Isobel Campbell                Saturday's Gone     3.5
# Dataset actualizado y guardado en: /content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv

# %%
music_df.rating.unique()
# Out:
# array([4.5, 5. , 2.5, 3.5, 4. , 1. , 1.5, 0.5, 2. , 3. ])

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56191 entries, 0 to 56190
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    56191 non-null  object
#  1   Artist      56191 non-null  object
#  2   Track       56191 non-null  object
#  3   Album       56191 non-null  object
#  4   Date        56191 non-null  object
#  5   Time        56191 non-null  object
#  6   Genre       56191 non-null  object
#  7   bert_input  56191 non-null  object
#  8   emotion     0 non-null      float64
#  9   rating      56191 non-null  float64
# dtypes: float64(2), object(8)
# memory usage: 4.3+ MB

# %%
# Seleccionar una muestra aleatoria de 1000 registros
sample_size = 1000
music_sample = music_df.sample(n=sample_size, random_state=42)

# Guardar la muestra en un archivo CSV para etiquetar manualmente
sample_output_path = '/content/drive/MyDrive/TFM/Datasets/music_sample_for_labeling.csv'
music_sample.to_csv(sample_output_path, index=False)

print(f"Muestra de 1000 registros guardada en: {sample_output_path}")
# Out:
# Muestra de 1000 registros guardada en: /content/drive/MyDrive/TFM/Datasets/music_sample_for_labeling.csv

# %%
music_sample = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/music_sample_for_labeling.csv')

# %%
music_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    1000 non-null   object
#  1   Artist      1000 non-null   object
#  2   Track       1000 non-null   object
#  3   Album       1000 non-null   object
#  4   Date        1000 non-null   object
#  5   Time        1000 non-null   object
#  6   Genre       1000 non-null   object
#  7   bert_input  1000 non-null   object
#  8   emotion     0 non-null      float64
#  9   rating      1000 non-null   float64
# dtypes: float64(2), object(8)
# memory usage: 78.2+ KB

# %%
music_sample.head()
# Out:
#      Username            Artist                           Track  \
# 0  massdosage              ABBA                  Hey, Hey Helen
# 1  Knapster01     Elvis Presley  (You're The) Devil in Disguise
# 2  massdosage             Bicep                         Sundial
# 3  Knapster01         Mushkilla        Big Smoke - Lavonz Remix
# 4     Babs_05  Boards of Canada             A Moment of Clarity
#
#                          Album         Date             Time  \
# 0                         ABBA  19 Jan 2021  0 days 04:35:00
# 1  Elvis' Gold Records, Vol. 4  17 Jan 2021  0 days 16:03:00
# 2                        Isles  31 Jan 2021  0 days 22:09:00
# 3                     RMX Dubs  23 Jan 2021  0 days 00:34:00
# 4       The Campfire Headphase  31 Jan 2021  0 days 18:59:00
#
#                Genre                                         bert_input  \
# 0                Pop                 ABBA | Hey, Hey Helen | ABBA | Pop
# ...

# %%
# !pip install xlsxwriter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 10.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# Cargar el dataset de música
file_path = "/content/drive/MyDrive/TFM/Datasets/music_sample_for_labeling.csv"
dataset = pd.read_csv(file_path)

# Convertir la columna 'emotion' a texto para las etiquetas
dataset['emotion'] = dataset['emotion'].astype(str)

# Lista de emociones
emotion_options = [
    "Happy", "Sad", "Nostalgic", "Excited", "Scared",
    "Angry", "Romantic", "Hopeful", "Funny", "Adventurous",
    "Suspenseful", "Inspiring", "Heartwarming"
]

# Función para etiquetar manualmente con etiquetas compuestas
def etiquetar_manual(df):
    print("Inicio del proceso de etiquetado manual. Escribe '0' para guardar y salir.\n")
    for index, row in df.iterrows():
        if row['emotion'] == "nan" or row['emotion'] == "":  # Solo procesar los no etiquetados
            print(f"\n=== Registro {index + 1}/{len(df)} ===")
            print(f"Artista: {row['Artist']}")
            print(f"Título: {row['Track']}")
            print(f"Álbum: {row['Album']}")
            print(f"Género: {row['Genre']}")
            print(f"Fecha: {row['Date']}")
            print(f"Hora: {row['Time']}")

            print("\nSelecciona una o más emociones separadas por comas (ej: 9,13):")
            for i, emotion in enumerate(emotion_options, 1):
                print(f"{i}. {emotion}")

            emotion_indices = input("\nEscribe los números de las emociones (o '0' para guardar y salir): ").strip()
            if emotion_indices == '0':
                print("\nGuardando progreso...")
                df.to_csv(file_path, index=False)
                print("Progreso guardado. ¡Hasta luego!")
                break

            try:
                selected_emotions = [emotion_options[int(i) - 1] for i in emotion_indices.split(",") if int(i) > 0 and int(i) <= len(emotion_options)]
                df.at[index, 'emotion'] = ", ".join(selected_emotions)
                print(f"Etiqueta '{', '.join(selected_emotions)}' guardada para el registro {index + 1}.\n")
            except (ValueError, IndexError):
                print("Entrada no válida. Intenta nuevamente con números separados por comas.")

    print("\n¡Todos los registros han sido etiquetados!")
    df.to_csv(file_path, index=False)
    return df

# Llamar a la función para iniciar el etiquetado
dataset = etiquetar_manual(dataset)
# Out:
# Inicio del proceso de etiquetado manual. Escribe '0' para guardar y salir.
#
#
# === Registro 1/1000 ===
# Artista: ABBA
# Título: Hey, Hey Helen
# Álbum: ABBA
# Género: Pop
# Fecha: 19 Jan 2021
# Hora: 0 days 04:35:00
#
# Selecciona una o más emociones separadas por comas (ej: 9,13):
# 1. Happy
# 2. Sad
# 3. Nostalgic
# 4. Excited
# 5. Scared
# 6. Angry
# 7. Romantic
# 8. Hopeful
# 9. Funny
# 10. Adventurous
# 11. Suspenseful
# 12. Inspiring
# 13. Heartwarming
#
# Escribe los números de las emociones (o '0' para guardar y salir): 1,3
# Etiqueta 'Happy, Nostalgic' guardada para el registro 1.
#
#
# === Registro 2/1000 ===
# Artista: Elvis Presley
# Título: (You're The) Devil in Disguise
# Álbum: Elvis' Gold Records, Vol. 4
# Género: Alternative/Indie
# Fecha: 17 Jan 2021
# Hora: 0 days 16:03:00
#
# Selecciona una o más emociones separadas por comas (ej: 9,13):
# 1. Happy
# 2. Sad
# 3. Nostalgic
# 4. Excited
# 5. Scared
# 6. Angry
# 7. Romantic
# 8. Hopeful
# 9. Funny
# ...

# %%
import pandas as pd

# Cargar el dataset de música
file_path = "/content/drive/MyDrive/TFM/Datasets/music_sample_for_labeling.csv"
music_dataset = pd.read_csv(file_path)

# Crear un archivo Excel para etiquetado manual
output_path = "/content/drive/MyDrive/TFM/Datasets/music_sample_for_manual_labeling.xlsx"

# Lista de emociones para agregar como referencia
emotion_options = [
    "1. Happy", "2. Sad", "3. Nostalgic", "4. Excited", "5. Scared",
    "6. Angry", "7. Romantic", "8. Hopeful", "9. Funny",
    "10. Adventurous", "11. Suspenseful", "12. Inspiring", "13. Heartwarming"
]

# Crear un DataFrame para la lista de emociones
emotions_df = pd.DataFrame({"Emotion Options": emotion_options})

# Crear un escritor de Excel
with pd.ExcelWriter(output_path, engine='xlsxwriter') as writer:
    # Guardar el dataset en la primera hoja
    music_dataset.to_excel(writer, sheet_name="Music Dataset", index=False)
    # Guardar las emociones en una segunda hoja
    emotions_df.to_excel(writer, sheet_name="Emotion Options", index=False)

print(f"Archivo Excel para etiquetado guardado en: {output_path}")
# Out:
# Archivo Excel para etiquetado guardado en: /content/drive/MyDrive/TFM/Datasets/music_sample_for_manual_labeling.xlsx

# %%
import pandas as pd

# Ruta del archivo original con etiquetas
file_path = "/content/drive/MyDrive/TFM/Datasets/music_sample_for_manual_labeling.xlsx"

# Cargar los datos
data = pd.read_excel(file_path, sheet_name="Music Dataset")  # Cambiar 'Music Dataset' si la hoja tiene otro nombre

# Mapeo de números a nombres de emociones
emotion_mapping = {
    1: "Happy", 2: "Sad", 3: "Nostalgic", 4: "Excited", 5: "Scared",
    6: "Angry", 7: "Romantic", 8: "Hopeful", 9: "Funny",
    10: "Adventurous", 11: "Suspenseful", 12: "Inspiring", 13: "Heartwarming"
}

# Función para convertir números a nombres y preservar el orden original
def map_emotions_preserve_order(emotion):
    if isinstance(emotion, str):
        # Dividir y mapear números a nombres respetando el orden
        parts = [part.strip() for part in emotion.split(',')]
        return ", ".join([emotion_mapping[int(part)] if part.isdigit() else part for part in parts])
    return emotion

# Aplicar la transformación
data['emotion'] = data['emotion'].apply(map_emotions_preserve_order)

# Guardar el archivo procesado
output_path = "/content/drive/MyDrive/TFM/Datasets/music_sample_ready_for_bert.csv"
data.to_csv(output_path, index=False)

print(f"Archivo con orden preservado guardado en: {output_path}")
# Out:
# Archivo con orden preservado guardado en: /content/drive/MyDrive/TFM/Datasets/music_sample_ready_for_bert.csv

# %%
sample_music_ready = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/music_sample_ready_for_bert.csv')

# %%
sample_music_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    1000 non-null   object
#  1   Artist      1000 non-null   object
#  2   Track       1000 non-null   object
#  3   Album       1000 non-null   object
#  4   Date        1000 non-null   object
#  5   Time        1000 non-null   object
#  6   Genre       1000 non-null   object
#  7   bert_input  1000 non-null   object
#  8   emotion     1000 non-null   object
#  9   rating      1000 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 78.2+ KB

# %%
sample_music_ready.emotion.unique()
# Out:
# array(['Happy, Nostalgic', 'Hopeful, Inspiring', 'Suspenseful, Excited',
#        'Hopeful, Heartwarming', 'Inspiring, Adventurous',
#        'Excited, Inspiring', 'Happy, Excited', 'Excited, Happy',
#        'Excited, Adventurous', 'Romantic, Excited', 'Heartwarming, Happy',
#        'Heartwarming, Excited', 'Sad, Nostalgic', 'Nostalgic, Hopeful',
#        'Happy, Adventurous', 'Suspenseful, Heartwarming',
#        'Adventurous, Romantic', 'Happy, Funny', 'Romantic, Inspiring',
#        'Suspenseful, Adventurous', 'Happy, Inspiring',
#        'Nostalgic, Adventurous', 'Excited, Hopeful',
#        'Inspiring, Romantic', 'Inspiring, Happy', 'Adventurous, Happy',
#        'Heartwarming, Hopeful', 'Adventurous, Excited',
#        'Romantic, Hopeful', 'Nostalgic, Inspiring',
#        'Suspenseful, Hopeful', 'Romantic, Heartwarming',
#        'Hopeful, Excited', 'Adventurous, Suspenseful', 'Nostalgic, Sad',
#        'Inspiring, Heartwarming', 'Nostalgic, Suspenseful',
# ...

# %%
sample_music_ready.emotion.value_counts()
# Out:
# emotion
# Sad, Inspiring               68
# Happy, Adventurous           52
# Happy, Inspiring             49
# Excited, Happy               40
# Adventurous, Happy           37
#                              ..
# Inspiring, Romantic           1
# Scared, Adventurous           1
# Heartwarming, Suspenseful     1
# Suspenseful, Hopeful          1
# Angry, Nostalgic              1
# Name: count, Length: 116, dtype: int64

# %% [markdown]
# # Sistema de Recomendación
#
# **Archivos Finales para trabajar con BERT**

# %% [markdown]
# **Muestra**

# %%
sample_music_ready = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/music_sample_ready_for_bert.csv')

# %%
sample_music_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    1000 non-null   object
#  1   Artist      1000 non-null   object
#  2   Track       1000 non-null   object
#  3   Album       1000 non-null   object
#  4   Date        1000 non-null   object
#  5   Time        1000 non-null   object
#  6   Genre       1000 non-null   object
#  7   bert_input  1000 non-null   object
#  8   emotion     1000 non-null   object
#  9   rating      1000 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 78.2+ KB

# %%
sample_music_ready.head()
# Out:
#      Username            Artist                           Track  \
# 0  massdosage              ABBA                  Hey, Hey Helen
# 1  Knapster01     Elvis Presley  (You're The) Devil in Disguise
# 2  massdosage             Bicep                         Sundial
# 3  Knapster01         Mushkilla        Big Smoke - Lavonz Remix
# 4     Babs_05  Boards of Canada             A Moment of Clarity
#
#                          Album         Date             Time  \
# 0                         ABBA  19 Jan 2021  0 days 04:35:00
# 1  Elvis' Gold Records, Vol. 4  17 Jan 2021  0 days 16:03:00
# 2                        Isles  31 Jan 2021  0 days 22:09:00
# 3                     RMX Dubs  23 Jan 2021  0 days 00:34:00
# 4       The Campfire Headphase  31 Jan 2021  0 days 18:59:00
#
#                Genre                                         bert_input  \
# 0                Pop                 ABBA | Hey, Hey Helen | ABBA | Pop
# ...

# %%
sample_music_ready.to_csv('/content/drive/MyDrive/TFM/Dataset_for_bert/sample_music_ready_for_bert.csv', index=False)

# %% [markdown]
# **Archivo Grande**

# %%
music_ready = pd.read_csv('/content/drive/MyDrive/TFM/Datasets/music_prepared_for_bert.csv')

# %%
music_ready.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56191 entries, 0 to 56190
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    56191 non-null  object
#  1   Artist      56191 non-null  object
#  2   Track       56191 non-null  object
#  3   Album       56191 non-null  object
#  4   Date        56191 non-null  object
#  5   Time        56191 non-null  object
#  6   Genre       56191 non-null  object
#  7   bert_input  56191 non-null  object
#  8   emotion     0 non-null      float64
#  9   rating      56191 non-null  float64
# dtypes: float64(2), object(8)
# memory usage: 4.3+ MB

# %%
music_ready.head()
# Out:
#   Username           Artist                          Track  \
# 0  Babs_05  Isobel Campbell     The Circus Is Leaving Town
# 1  Babs_05  Isobel Campbell                   Dusty Wreath
# 2  Babs_05  Isobel Campbell     Honey Child What Can I Do?
# 3  Babs_05  Isobel Campbell  It's Hard To Kill A Bad Thing
# 4  Babs_05  Isobel Campbell                Saturday's Gone
#
#                        Album         Date             Time              Genre  \
# 0  Ballad of the Broken Seas  31 Jan 2021  0 days 23:36:00  Alternative/Indie
# 1  Ballad of the Broken Seas  31 Jan 2021  0 days 23:32:00  Alternative/Indie
# 2  Ballad of the Broken Seas  31 Jan 2021  0 days 23:28:00  Alternative/Indie
# 3  Ballad of the Broken Seas  31 Jan 2021  0 days 23:25:00  Alternative/Indie
# 4  Ballad of the Broken Seas  31 Jan 2021  0 days 23:21:00  Alternative/Indie
#
#                                           bert_input  emotion  rating
# 0  Isobel Campbell | The Circus Is Leaving Town |...      NaN     4.5
# ...

# %%
music_ready.to_csv('/content/drive/MyDrive/TFM/Dataset_for_bert/music_ready_for_bert.csv', index=False)

# %% [markdown]
# #Estandarizar los generos

# %%
# Importar librerías necesarias
import pandas as pd

# Cargar el dataset completo 'music_ready_for_bert.csv'
music_ready_path = '/content/drive/MyDrive/TFM/Dataset_for_bert/music_ready_for_bert.csv'
music_ready_df = pd.read_csv(music_ready_path)

# **Estandarización de Géneros**
# Mapeo de géneros musicales a categorías narrativas
genre_mapping = {
    "Alternative/Indie": ["Drama", "Nostalgic"],
    "Blues/Jazz": ["Sad", "Nostalgic", "Drama"],
    "Classical": ["Heartwarming", "Drama"],
    "Country/Folk": ["Heartwarming", "Nostalgic"],
    "Electronic": ["Science Fiction", "Action"],
    "Experimental": ["Suspense", "Science Fiction"],
    "Hip-Hop/Rap": ["Action", "Suspense"],
    "Metal": ["Action", "Drama"],
    "Musical": ["Comedy", "Romance"],
    "Pop": ["Comedy", "Romance"],
    "Rock": ["Action", "Drama"],
    "Soundtrack": ["Heartwarming", "Suspense"],
}

# Dividir géneros y mapearlos
music_ready_df['standard_genres'] = music_ready_df['Genre'].str.split('|').apply(
    lambda genres: list(set([cat for g in genres if g in genre_mapping for cat in genre_mapping[g]]))
)

# Guardar el dataset completo actualizado
updated_music_ready_path = '/content/drive/MyDrive/TFM/Dataset_for_bert/music_ready_for_bert_with_standard_genres.csv'
music_ready_df.to_csv(updated_music_ready_path, index=False)
print(f"Dataset completo actualizado guardado en: {updated_music_ready_path}")
# Out:
# Dataset completo actualizado guardado en: /content/drive/MyDrive/TFM/Dataset_for_bert/music_ready_for_bert_with_standard_genres.csv

# %%
# Importar librerías necesarias
import pandas as pd

# Cargar el dataset completo 'music_ready_for_bert.csv'
music_ready_path = '/content/drive/MyDrive/TFM/Dataset_for_bert/sample_music_ready_for_bert.csv'
music_ready_df = pd.read_csv(music_ready_path)

# **Estandarización de Géneros**
# Mapeo de géneros musicales a categorías narrativas
genre_mapping = {
    "Alternative/Indie": ["Drama", "Nostalgic"],
    "Blues/Jazz": ["Sad", "Nostalgic", "Drama"],
    "Classical": ["Heartwarming", "Drama"],
    "Country/Folk": ["Heartwarming", "Nostalgic"],
    "Electronic": ["Science Fiction", "Action"],
    "Experimental": ["Suspense", "Science Fiction"],
    "Hip-Hop/Rap": ["Action", "Suspense"],
    "Metal": ["Action", "Drama"],
    "Musical": ["Comedy", "Romance"],
    "Pop": ["Comedy", "Romance"],
    "Rock": ["Action", "Drama"],
    "Soundtrack": ["Heartwarming", "Suspense"],
}

# Dividir géneros y mapearlos
music_ready_df['standard_genres'] = music_ready_df['Genre'].str.split('|').apply(
    lambda genres: list(set([cat for g in genres if g in genre_mapping for cat in genre_mapping[g]]))
)

# Guardar el dataset completo actualizado
updated_music_ready_path = '/content/drive/MyDrive/TFM/Dataset_for_bert/sample_music_ready_for_bert_with_standard_genres.csv'
music_ready_df.to_csv(updated_music_ready_path, index=False)
print(f"Dataset completo actualizado guardado en: {updated_music_ready_path}")
# Out:
# Dataset completo actualizado guardado en: /content/drive/MyDrive/TFM/Dataset_for_bert/sample_music_ready_for_bert_with_standard_genres.csv

# %%
df = pd.read_csv('/content/drive/MyDrive/TFM/Dataset_for_bert/music_ready_for_bert_with_standard_genres.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56191 entries, 0 to 56190
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Username         56191 non-null  object
#  1   Artist           56191 non-null  object
#  2   Track            56191 non-null  object
#  3   Album            56191 non-null  object
#  4   Date             56191 non-null  object
#  5   Time             56191 non-null  object
#  6   Genre            56191 non-null  object
#  7   bert_input       56191 non-null  object
#  8   emotion          0 non-null      float64
#  9   rating           56191 non-null  float64
#  10  standard_genres  56191 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 4.7+ MB

# %%
df.standard_genres.unique()
# Out:
# array(["['Drama', 'Nostalgic']", "['Science Fiction', 'Action']",
#        "['Comedy', 'Romance']", "['Suspense', 'Action']",
#        "['Drama', 'Heartwarming']", "['Suspense', 'Heartwarming']",
#        "['Drama', 'Nostalgic', 'Sad']", "['Science Fiction', 'Suspense']",
#        "['Drama', 'Action']", "['Nostalgic', 'Heartwarming']"],
#       dtype=object)

# %%
df.standard_genres.value_counts()
# Out:
# standard_genres
# ['Drama', 'Action']                20559
# ['Comedy', 'Romance']              11627
# ['Drama', 'Nostalgic']              9632
# ['Science Fiction', 'Action']       9113
# ['Suspense', 'Action']              2281
# ['Nostalgic', 'Heartwarming']        972
# ['Drama', 'Nostalgic', 'Sad']        709
# ['Suspense', 'Heartwarming']         517
# ['Drama', 'Heartwarming']            473
# ['Science Fiction', 'Suspense']      308
# Name: count, dtype: int64

# %%
dfm = pd.read_csv('/content/drive/MyDrive/TFM/Dataset_for_bert/sample_music_ready_for_bert_with_standard_genres.csv')

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Username         1000 non-null   object
#  1   Artist           1000 non-null   object
#  2   Track            1000 non-null   object
#  3   Album            1000 non-null   object
#  4   Date             1000 non-null   object
#  5   Time             1000 non-null   object
#  6   Genre            1000 non-null   object
#  7   bert_input       1000 non-null   object
#  8   emotion          1000 non-null   object
#  9   rating           1000 non-null   float64
#  10  standard_genres  1000 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 86.1+ KB

# %%
dfm.standard_genres.unique()
# Out:
# array(["['Comedy', 'Romance']", "['Drama', 'Nostalgic']",
#        "['Science Fiction', 'Action']", "['Drama', 'Action']",
#        "['Drama', 'Heartwarming']", "['Science Fiction', 'Suspense']",
#        "['Drama', 'Nostalgic', 'Sad']", "['Nostalgic', 'Heartwarming']",
#        "['Suspense', 'Action']", "['Suspense', 'Heartwarming']"],
#       dtype=object)

# %%
dfm.standard_genres.value_counts()
# Out:
# standard_genres
# ['Drama', 'Action']                378
# ['Comedy', 'Romance']              197
# ['Science Fiction', 'Action']      169
# ['Drama', 'Nostalgic']             165
# ['Suspense', 'Action']              43
# ['Drama', 'Heartwarming']           12
# ['Drama', 'Nostalgic', 'Sad']       12
# ['Nostalgic', 'Heartwarming']       10
# ['Suspense', 'Heartwarming']        10
# ['Science Fiction', 'Suspense']      4
# Name: count, dtype: int64

# %%
dfm.to_csv('/content/drive/MyDrive/TFM/Dataset_for_bert/sample_music_ready_for_bert.csv', index=False)

# %%
df.to_csv('/content/drive/MyDrive/TFM/Dataset_for_bert/music_ready_for_bert.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56191 entries, 0 to 56190
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Username         56191 non-null  object
#  1   Artist           56191 non-null  object
#  2   Track            56191 non-null  object
#  3   Album            56191 non-null  object
#  4   Date             56191 non-null  object
#  5   Time             56191 non-null  object
#  6   Genre            56191 non-null  object
#  7   bert_input       56191 non-null  object
#  8   emotion          0 non-null      float64
#  9   rating           56191 non-null  float64
#  10  standard_genres  56191 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 4.7+ MB

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Username         1000 non-null   object
#  1   Artist           1000 non-null   object
#  2   Track            1000 non-null   object
#  3   Album            1000 non-null   object
#  4   Date             1000 non-null   object
#  5   Time             1000 non-null   object
#  6   Genre            1000 non-null   object
#  7   bert_input       1000 non-null   object
#  8   emotion          1000 non-null   object
#  9   rating           1000 non-null   float64
#  10  standard_genres  1000 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 86.1+ KB
